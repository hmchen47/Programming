# %%
''' crescentmoon image downloader'''

import urllib
import urllib.request
import re
from bs4 import BeautifulSoup

urlArchive = "http://crescentmoon06.tumblr.com/archive"

htmlpage = urllib.request.urlopen(urlArchive).read()

soup = BeautifulSoup(htmlpage, "html.parser")

print(soup.prettify()[0:1000])

# lists = soup.findAll('a',{"hover"})
lists = soup.findAll('a',{"class": "hover"})

for elt in lists:
    print(elt)

regex = 'href="(http://crescentmoon06.tumblr.com/post/[0-9]*)"'

pattern = re.compile(regex)
# print(pattern)

# print(lists[0])
# print((pattern.findall(str(lists[0]))))

refLst = [pattern.findall(str(elt)) for elt in lists if pattern.findall(str(elt)) != []]

printf(refList)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="off" http-equiv="x-dns-prefetch-control"/>
#   <meta content="width=device-width" name="viewport">
#    <title>
#     crescentmoon: Archive
#    </title>
#    <link href="http://33.media.tumblr.com/avatar_5fdffb6916e2_128.png" rel="icon" type="image/png"/>
#    <link href="http://assets.tumblr.com/client/prod/app/styles/global.css?_v=ff85367d812f59000ca4fc4a8e5059fc" media="screen" rel="stylesheet">
#     <link href="http://assets.tumblr.com/client/prod/app/context/archive/styles.css?_v=a4d5cfd38ca3fdfe6a946a5536db762b" media="screen" rel="stylesheet">
#      <script>
#       var _flags = '
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142624779513" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 11, 2016</span><span class="post_notes" data-notes="1144">1,144 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142624764973" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 11, 2016</span><span class="post_notes" data-notes="868">868 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142624741238/big-sur-julia-pfeiffer-state-park-central" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 11, 2016</span><span class="post_notes" data-notes="24">24 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142624675338" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 11, 2016</span><span class="post_notes" data-notes="66">66 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142624661453" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 11, 2016</span><span class="post_notes" data-notes="17">17 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142623962593" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 11, 2016</span><span class="post_notes" data-notes="771">771 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505643393" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="4100">4,100 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505617173" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="622">622 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505584913" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="584">584 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505542613" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="2245">2,245 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505523578" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="1329">1,329 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505462768/nrjizer-archive" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="1715">1,715 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505425058" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="809">809 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505406588/a-simple-man-of-55-love-her-ink" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="847">847 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505381433" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="1075">1,075 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505332078" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="356">356 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505303398" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="71">71 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505204248/crescentmoon06-royal-albert-bridge-plymouth" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="306">306 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505180953/infinimorr-zzz" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="5930">5,930 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505152338/crescentmoon06-by-sanja-dedić-koprivnica" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="181">181 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505083838/crescentmoon06-kilchurn-castle-sxv-scotland" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="462">462 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505062303" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="95">95 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142505017468/nrjizer-archive" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="628">628 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142504968968" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="1227">1,227 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142504918428/red-skies-over-man-owar" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="29">29 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142504874088" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="1776">1,776 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142504853173/seabiscut8-spanish-galion" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="953">953 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142504824733" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="87">87 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142504733608" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 9, 2016</span><span class="post_notes" data-notes="246">246 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142451009008" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="35">35 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450962583/iluvbillyelliot-sea-goddess" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="773">773 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450908793/photo-by-andreyrazoomovsky" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="45">45 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450873973/between-showers-by-katieb" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="33">33 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450817653" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="39">39 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450788113" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="28">28 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450732433" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="111">111 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450698853/peggys-cove-nova-scotia-canada" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="37">37 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450655858/schwein-child-body-vase-by-torkil-gudnason" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="100">100 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450639523/peggys-cove-nova-scotia-canada" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="28">28 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450597458" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="57">57 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450412663" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="89">89 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450389338" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="53">53 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450353913/free-style-dreams" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="400">400 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450309043" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="27">27 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450242428" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="1409">1,409 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450228458/photo-by-fly10" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="12">12 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142450196023/photo-by-ippei-janine" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 8, 2016</span><span class="post_notes" data-notes="18">18 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142397746493" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 7, 2016</span><span class="post_notes" data-notes="1524">1,524 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142397719423" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 7, 2016</span><span class="post_notes" data-notes="106">106 notes</span></div><div class="hover_tags"></div></a>
# <a class="hover" href="http://crescentmoon06.tumblr.com/post/142397617328" target="_blank" title=""><div class="hover_inner"><span class="post_date">Apr 7, 2016</span><span class="post_notes" data-notes="1087">1,087 notes</span></div><div class="hover_tags"></div></a>

# %%
'''Freely image downloader'''

import urllib
import urllib.request
import re
from bs4 import BeautifulSoup

urlArchive = "http://feedly.com/i/category/Entertainment-H"

htmlpage = urllib.request.urlopen(urlArchive).read()

soup = BeautifulSoup(htmlpage, "html.parser")

# print(soup.prettify()[0:1000])
print(soup.prettify())

# # lists = soup.findAll('a',{"hover"})
# lists = soup.findAll('a',{"class": "hover"})

# for elt in lists:
#     print(elt)

# regex = 'href="(http://crescentmoon06.tumblr.com/post/[0-9]*)"'

# pattern = re.compile(regex)
# # print(pattern)

# # print(lists[0])
# # print((pattern.findall(str(lists[0]))))

# refLst = [pattern.findall(str(elt)) for elt in lists if pattern.findall(str(elt)) != []]
# Out:
# <!DOCTYPE doctype html>
# <html itemscope="" itemtype="http://schema.org/WebPage">
#  <head>
#   <meta charset="utf-8">
#    <!-- Place this data between the <head> tags of your website -->
#    <title>
#     feedly. Read more, know more.
#    </title>
#    <meta content="feedly: organize, read and share what matters to you." name="description"/>
#    <link color="#2bb24c" href="//s3.feedly.com/img/feedly-icon.svg" rel="mask-icon">
#     <link href="http://blog.feedly.com/feed/" rel="alternate" title="feedly blog" type="application/rss+xml"/>
#     <!-- Google Authorship and Publisher Markup -->
#     <link href="https://plus.google.com/+feedly/posts" rel="author"/>
#     <link href="https://plus.google.com/+feedly" rel="publisher">
#      <!-- Schema.org markup for Google+ -->
#      <meta content="seCC5Sl_unJ5sOVffmEr5lqE0mIejWj0U7x4zC1Cc1Q" name="google-site-verification"/>
#      <meta content="zS8-4uZ25VsSVdlKO0932IjeTAoC-s_qWg6VPfSiTNc" name="google-site-verification"/>
#      <meta content="feedly: organize, read and share what matters to you." itemprop="name">
#       <meta content="Feedly connects you to the information and knowledge you care about. We help you get more out of you work, education, hobbies and interests. The feedly platform lets you discover sources of quality content, follow and read everything those sources publish with ease and organize everything in one place." itemprop="description">
#        <meta content="http://s3.feedly.com/img/feedly-512.png" itemprop="image">
#         <!-- Twitter Card data -->
#         <meta content="summary_large_image" name="twitter:card">
#          <meta content="@feedly" name="twitter:site">
#           <meta content="feedly: organize, read and share what matters to you." name="twitter:title">
#            <meta content="Feedly connects you to the information and knowledge you care about. We help you get more out of you work, education, hobbies and interests. The feedly platform lets you discover sources of quality content, follow and read everything those sources publish with ease and organize everything in one place." name="twitter:description">
#             <meta content="@feedly" name="twitter:creator">
#              <!-- Twitter summary card with large image must be at least 280x150px -->
#              <meta content="http://feedly.com/index.html" name="twitter:image:src">
#               <!-- Open Graph data -->
#               <meta content="http://feedly.com/index.html" property="og:url">
#                <meta content="feedly" property="og:site_name">
#                 <meta content="http://s3.feedly.com/img/feedly-512.png" property="og:image">
#                  <meta content="feedly: organize, read and share what matters to you." property="og:title">
#                   <meta content="Feedly connects you to the information and knowledge you care about. We help you get more out of you work, education, hobbies and interests. The feedly platform lets you discover sources of quality content, follow and read everything those sources publish with ease and organize everything in one place." property="og:description">
#                    <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" id="vp" name="viewport"/>
#                    <link href="https://plus.google.com/114279580480116116957/" rel="publisher">
#                     <link href="https://chrome.google.com/webstore/detail/hipbfijinpcgfogaopmgehiegacbhmob" rel="chrome-webstore-item">
#                      <base href="//s3.feedly.com/production/head/"/>
#                      <link href="//s3.feedly.com/web/30.0.1154/fx/feedly-fx.css" rel="stylesheet" type="text/css">
#                       <style>
#                        #feedlyBlocked
# 			{
# 				transition: opacity 1s linear;
# 			}
#
# 			.center
# 		    {
# 		        margin: 0 auto;
# 		    }
#
# 			#feedlySplashscreen
# 			{
#   		 		position	: absolute;
#     			top			: 50%;
#     			left		: 0;
#     			transform	: translateX(0) translateY(-50%);
#     			font-size	: 44px;
#     			color		: #D6D6D6;
#     			font-weight	: bold;
#     			font-family : helvetica, sans-serif;
#     			letter-spacing: -0.04em;
#     			text-align	: center;
#     			width		: 100%;
# 			}
#
# 			#feedlyStaticProgressBar
# 			{
#   		 		position	: absolute;
#     			top			: 0;
#     			left		: 0;
#     			width		: 1px;
#     			height		: 3px;
#     			background-color: #CCC;
#     			text-align	: center;
# 			}
#
# 			#feedlyStaticProgressMessage
# 			{
# 				font-size	: 13px;
# 				color		: #CFCFCF;
#     			font-family : helvetica, sans-serif;
#     			line-height	: 4em;
#     			letter-spacing: 0em;
#     			font-weight : normal;
#     			display		: none;
# 			}
#                       </style>
#                       <script>
#                        var feedlyT0 = new Date().getTime();
#
# 	    	function fromFeedlyT0(){
# 	    		return new Date().getTime() - feedlyT0;
# 	    	}
#
# 	    	function getFeedlyCookie()
# 	    	{
# 	    		try
# 	    		{
# 		   			var nameEQ = "feedly.session=";
# 		   			var ca = document.cookie.split(';');
# 		   			for(var i=0;i < ca.length;i++) {
# 		   				var c = ca[i];
# 		   				while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 		   				if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# 		   			}
# 		   			return null;
# 	    		}
# 	    		catch( e )
# 	    		{
# 	    			return null;
# 	    		}
# 	    	}
#
#     		var errorTimer = window.setTimeout( function(){
#                	// The page has successfully loaded.
#             	var blockedElemend = document.getElementById( "feedlyBlocked" );
#                 if( blockedElemend == null )
#                 	return;
#
#             	handleError()
#             },
#             15000
#             );
#
#             function handleError()
#             {
#             	if( errorTimer != null )
#             	{
#             		window.clearTimeout( errorTimer );
#             		errorTimer = null;
#             	}
#
#             	// if loading from http, then redirect to https to avoid CDN
#             	if( document.location.protocol == "http" )
#             	{
#             		document.location = "https://feedly.com/";
#             		return;
#             	}
#             	else
#             	{
#                    	// The page has successfully loaded.
#                 	var blockedElemend = document.getElementById( "feedlyBlocked" );
#                     if( blockedElemend != null )
# 	            		blockedElemend.style.opacity = 1;
#
#                     document.getElementById( "feedlyStaticProgressBar" ).style.display = "none";
#                     document.getElementById( "feedlySplashscreen" ).style.display = "none";
#             	}
#             }
#
# 			try
#         	{
#         		// MAPPING VERSION 4
# 		    	//
# 		    	// if this is an old URL, we should redirect it to the new URL format
# 		    	// OLD http://feedly.com/beta#welcome
# 		    	// NEW http://feedly.com/b/welcome
#
# 		    	var h = window.location.hash;             // example #welcome
# 		    	if( h.indexOf( "#" ) == 0 )
# 		    		h = h.slice( 1 );
#
# 		    	var p = window.location.pathname;         // example / /beta /dev.html /index.html
#
# 		    	var host = window.location.host;          // example feedly.com or cloud.feedly.com
#
# 		    	var protocol = window.location.protocol;  // example http: or https:
#
# 		    	// CASE 0 - Old hosts (example: cloud.feedly.com or www.feedly.com)
# 		    	if( window.location.host != "feedly.com" && window.location.host != "sandbox.feedly.com" )
# 		    	{
# 					window.location = window.location.protocol + "//feedly.com" + p + window.location.hash;
# 		    	}
# 		    	else if( p == "/home" )
# 		    	{
# 					window.location = window.location.protocol + "//feedly.com/i/" + h;
# 		    	}
# 		    	// CASE 1 - We have an old hash URL
# 		    	else if( h.length > 0 )
# 		    	{
# 		    		console.log( "[feedly] need to map hash:" + h + " pathname:" + p );
# 		    		switch( p )
# 		    		{
# 		    			case "/beta":
# 		    				window.location.href = window.location.protocol + "//feedly.com/b/" + h;
# 		    				break;
#
# 		    			case "/alpha.html":
# 		    				window.location.href = window.location.protocol + "//feedly.com/a/" + h;
# 		        			break;
#
# 		    			case "/dev.html":
# 		    				window.location.href = window.location.protocol + "//feedly.com/d/" + h;
# 		        			break;
#
# 		    			case "/home":
# 		    			case "/index.html":
# 		    			case "/":
# 		    				window.location.href = window.location.protocol + "//feedly.com/i/" + h;
# 		        			break;
#
# 		    			default:
# 		    				// We must be in a case where
# 		    				// http://feedly.com/i/subscription/feed/....
# 		    				// where the feed id has a hash.
# 		    		}
# 		    	}
# 		    	else if( p.indexOf( ".html" ) > 0 )
# 				{
# 			    	// CASE 2 - Old pathnames
# 			   		switch( p )
# 			   		{
# 			   			case "/alpha.html":
# 			   				window.location.href = window.location.protocol + "//feedly.com/a";
# 			       			break;
#
# 			   			case "/dev.html":
# 			   				window.location.href = window.location.protocol + "//feedly.com/d";
# 			       			break;
#
# 			   			case "/index.html":
# 			   				window.location.href = window.location.protocol + "//feedly.com/";
# 			       			break;
#
# 			   			default:
# 			   		}
# 				}
#
# 		    }
# 		    catch( e )
# 		    {
# 		        // ignore
# 		        console.log( "[feedly] url mapping failed:" + e.name + " -- " + e.message )
# 		        window.location.href = "https://feedly.com/";
# 		    }
#
# 		    var feedlyProgressCounter  = 0;
# 		    var feedlyProgressDuration = 1000;
# 		    var feedlyProgressSteps	   = 50;
#             var feedlyProgressInterval = window.setInterval( function(){
#
#             	if( window.location.pathname.indexOf( "/pro" ) == 2 )
#             	{
#             		window.clearInterval( feedlyProgressInterval );
#             		return;
#             	}
#
#             	feedlyProgressCounter++;
#
#             	if( feedlyProgressCounter == 1 )
#             	{
#             		var pbElem = document.getElementById( "feedlyStaticProgressBar" );
#             		if( pbElem != null )
#             			pbElem.style.display = "block";
#
#             		var psElem = document.getElementById( "feedlySplashscreen" );
#             		if( psElem != null )
#             			psElem.style.display = "block";
#
#             		var wmElem = document.getElementById( "feedlyStaticProgressMessage" );
#             		if( wmElem != null )
#             		{
#                 		var fc = getFeedlyCookie();
#                 		if( fc != null )
#                 		{
#                 			wmElem.innerHTML = "Welcome back!";
#                 		}
#                 		else
#                 		{
#                 			wmElem.innerHTML = "Welcome!";
#                 		}
#             		}
#             	}
#
#             	if( feedlyProgressCounter > feedlyProgressSteps )
#             	{
#             		window.clearInterval( feedlyProgressInterval );
#             		return;
#             	}
#
#             	var pbElem = document.getElementById( "feedlyStaticProgressBar" );
#             	if( pbElem == null )
#             		window.clearInterval( feedlyProgressInterval );
#             	else
#             		pbElem.style.width = parseInt ( feedlyProgressCounter / feedlyProgressSteps * window.innerWidth ) + "px";
#             },
#             parseInt( feedlyProgressDuration / feedlyProgressSteps )
#             );
#                       </script>
#                      </link>
#                     </link>
#                    </link>
#                   </meta>
#                  </meta>
#                 </meta>
#                </meta>
#               </meta>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="home" id="box">
#   <div id="feedlyStaticProgressBar" style="display:none">
#   </div>
#   <div id="feedlySplashscreen" style="display:none">
#    feedly
#    <div id="feedlyStaticProgressMessage">
#    </div>
#   </div>
#   <div id="feedlyBlocked" style="opacity:0; font-family: sans-serif; text-align:left; color:#666; max-width:600px; padding-top: 60px; padding-left: 40px; line-height: 1.45em; font-size: 18px; padding-right:40px; margin-left:auto; margin-right:auto">
#    <img alt="" class="center" src="//s3.feedly.com/img/oops.png"/>
#    <br>
#     <br>
#      <strong style="color:#333">
#       Is feedly blocked?
#      </strong>
#      <br>
#       Feedly is not able to load. It is probably because one of your extensions is blocking it. If you run Adblock,
#     		HTTPSEverywhere, Awesome screenshot etc.. please make sure that feedly.com is white listed.
#       <br>
#        <a href="https://plus.google.com/communities/113648582731838175643/stream/3ed6de2d-8358-4390-86b1-a592ca6e8cf4">
#         Ask a question
#        </a>
#       </br>
#      </br>
#     </br>
#    </br>
#   </div>
#   <!--  FEEDLY UI SCRIPTS  -->
#   <script onerror="handleError()" src="//s3.feedly.com/web/30.0.1154/js/web-main-bundle.js" type="text/javascript">
#   </script>
#   <script onerror="handleError()" src="//s3.feedly.com/web/30.0.1154/js/web-templates-bundle.js" type="text/javascript">
#   </script>
#   <!--  FEEDLY UI SCRIPTS  -->
#  </body>
# </html>
